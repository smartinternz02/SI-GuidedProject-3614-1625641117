# %% [markdown]
# # Assignment 3 - Matplotlib and Seaborn

# %% [markdown]
# **Atharva Ramgirkar 19BCE0114**

# %% [markdown]
# ### <center>Table of Content</center>
#
# * [Importing Libraries](#Importing-Libraries)
# * [Getting the data](#Getting-the-data)
# * [Matplotlib Visualizations](#Matplotlib-Visualizations)
#     * [Line Plot](#Line-Plot)
#     * [Scatter Plot](#Scatter-Plot)
#     * [Bar Plot](#Bar-Plot)
#     * [Pie Chart](#Pie-Chart)
# * [Seaborn Visualizations](#Seaborn-Visualizations)
#     * [Scatter Plot](#Scatter-Plot)
#     * [Line Plot](#Line-Plot)
#     * [Count Plot](#Count-Plot)
#     * [Box Plot](#Box-Plot)
#     * [Pair Plot](#Pair-Plot)
#     * [Correlation Matrix](#Correlation-Matrix)
#     * [Heat Map](#Heat-Map)

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Getting the data

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Matplotlib Visualizations

# %% [markdown]
# #### Line Plot

# %%
plt.plot(np.linspace(10,20),
         np.linspace(15,25),
         color = "blue",
         label = "x v/s y")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()

# %% [markdown]
# #### Scatter Plot

# %%
plt.scatter(iris.sepal_length,iris.sepal_width)
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.title("Sepal Width v/s Length")
plt.show()

# %% [markdown]
# #### Bar Plot

# %%
plt.bar(iris.species,iris.petal_length,color = "blue")
plt.xlabel("Species")
plt.ylabel("Petal Length")
plt.title("Petal Length DIstribution of different Iris Species")
plt.show()

# %% [markdown]
# #### Pie Chart

# %%
plt.pie(list(iris.species.value_counts()),
        labels = iris.species.unique(),
        autopct= '%0.3f%%',
        colors = ["purple","pink","yellow"])
plt.show()

# %% [markdown]
# ### Seaborn Visualizations

# %% [markdown]
# #### Scatter Plot

# %%
sns.scatterplot(x="petal_length",y = "petal_width",data = iris)
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %% [markdown]
# #### Line Plot

# %%
sns.lineplot(x = "petal_length",y = "petal_width",data = iris)
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %%
sns.lineplot(x = "sepal_length",y = "sepal_width",data = iris)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# #### Count Plot

# %%
sns.countplot(x = "species",data = iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %% [markdown]
# #### Box Plot

# %%
sns.boxplot(x ="petal_width",data = iris)
# Out:
# <AxesSubplot:xlabel='petal_width'>

# %%
sns.boxplot(x ="petal_length",data = iris)
# Out:
# <AxesSubplot:xlabel='petal_length'>

# %%
sns.boxplot(x ="sepal_length",data = iris)
# Out:
# <AxesSubplot:xlabel='sepal_length'>

# %% [markdown]
# #### Categorical Plot

# %%
iris["petal_length_cat"] = np.where(iris["petal_length"]<2,
                                    "<2",
                                    np.where(iris["petal_length"]<4,
                                             "<4",
                                             ">4"))

# %%
sns.catplot(x="petal_length_cat",
            y= "sepal_length",
            hue = "species",
            kind = "bar",
            data = iris)

# %% [markdown]
# #### Pair Plot

# %%
sns.pairplot(iris)

# %% [markdown]
# #### Correlation Matrix

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %% [markdown]
# #### Heat Map

# %%
sns.heatmap(iris.corr(),
           annot=True,
           fmt=".2f", 
           linewidths=5,
           cmap=sns.diverging_palette(0,
                                      230,
                                      90,
                                      60,
                                      as_cmap=True),
           vmin=-1,
           vmax=1, 
           square=True)
# Out:
# <AxesSubplot:>
